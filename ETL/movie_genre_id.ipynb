# %%
import pandas as pd
import numpy as np
import os
import re
import json

from sqlalchemy import create_engine
import psycopg2

# %%
movies_sample = pd.read_csv('movies_metadata.csv', low_memory = False,)

# %%
movies_sample.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
# Out:
#      budget     id  popularity      revenue              title  vote_average
# 0  30000000    862   21.946943  373554033.0          Toy Story           7.7
# 1  65000000   8844   17.015539  262797249.0            Jumanji           6.9
# 3  16000000  31357    3.859495   81452156.0  Waiting to Exhale           6.1
# 5  60000000    949   17.924927  187436818.0               Heat           7.7
# 6  58000000  11860    6.677277          0.0            Sabrina           6.2

# %%
cleaned_movies_sample_df.to_csv('clean_movies.csv', index=False)

# %%
from config import db_password
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31880\3835622724.py in <module>
# ----> 1 from config import db_password
#
# ModuleNotFoundError: No module named 'config'

# %%
#connect to sql data base
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Final_Project"
engine = create_engine(db_string)
cleaned_movies_sample_df.to_sql(name='movie_sample_data', con=engine, if_exists ='replace')
rows_imported = 0

# %%
genres_df = movies_sample[['genres', 'id']]
genres_df
# Out:
#                                                   genres      id
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4                         [{'id': 35, 'name': 'Comedy'}]   11862
# ...                                                  ...     ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...  439050
# 45462                      [{'id': 18, 'name': 'Drama'}]  111109
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45464                                                 []  227506
# 45465                                                 []  461257
#
# [45466 rows x 2 columns]

# %%
index = 0
while index < len(genres_df):
    for key in genres[1]:
        print(dataList[1][name])
    index += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31880\870215348.py in <module>
#       2 while index < len(genres_df):
#       3     for key in genres[1]:
# ----> 4         print(dataList[1][name])
#       5     index += 1
#
# NameError: name 'dataList' is not defined

# %%
all_genres = []
for genre in genres_df.iterrows():
    genres = genre[1]['genres'].replace("'", "\"")
    genre_json = json.loads(genres)
    #print(genre_json)
    all_genres +=genre_json

# %%
len(all_genres)
# Out:
# 91106

# %%
genre_df = all_genres

# %%
genre_df
# Out:
# [{'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 35, 'name': 'Comedy'},
# ...

# %%
movie_genres = []
for row in genres_df.iterrows():
    genres = row[1]['genres'].replace("'", "\"")
    genre_json = json.loads(genres)
    movie_id = row[1]['id']
    for genre in genre_json:
        movie_genres.append({'id':movie_id, "genre_id": genre["id"], "genre": genre["name"]})

# %%
movie_genres
# Out:
# [{'id': '862', 'genre_id': 16, 'genre': 'Animation'},
#  {'id': '862', 'genre_id': 35, 'genre': 'Comedy'},
#  {'id': '862', 'genre_id': 10751, 'genre': 'Family'},
#  {'id': '8844', 'genre_id': 12, 'genre': 'Adventure'},
#  {'id': '8844', 'genre_id': 14, 'genre': 'Fantasy'},
#  {'id': '8844', 'genre_id': 10751, 'genre': 'Family'},
#  {'id': '15602', 'genre_id': 10749, 'genre': 'Romance'},
#  {'id': '15602', 'genre_id': 35, 'genre': 'Comedy'},
#  {'id': '31357', 'genre_id': 35, 'genre': 'Comedy'},
#  {'id': '31357', 'genre_id': 18, 'genre': 'Drama'},
#  {'id': '31357', 'genre_id': 10749, 'genre': 'Romance'},
#  {'id': '11862', 'genre_id': 35, 'genre': 'Comedy'},
#  {'id': '949', 'genre_id': 28, 'genre': 'Action'},
#  {'id': '949', 'genre_id': 80, 'genre': 'Crime'},
#  {'id': '949', 'genre_id': 18, 'genre': 'Drama'},
#  {'id': '949', 'genre_id': 53, 'genre': 'Thriller'},
#  {'id': '11860', 'genre_id': 35, 'genre': 'Comedy'},
#  {'id': '11860', 'genre_id': 10749, 'genre': 'Romance'},
# ...

# %%
genres_id_df = pd.DataFrame(movie_genres)

# %%
genres_id_df
# Out:
#            id  genre_id      genre
# 0         862        16  Animation
# 1         862        35     Comedy
# 2         862     10751     Family
# 3        8844        12  Adventure
# 4        8844        14    Fantasy
# ...       ...       ...        ...
# 91101  439050     10751     Family
# 91102  111109        18      Drama
# 91103   67758        28     Action
# 91104   67758        18      Drama
# 91105   67758        53   Thriller
#
# [91106 rows x 3 columns]

# %%
genres_id_df.to_csv('./genres_id_df.csv', index=False)
